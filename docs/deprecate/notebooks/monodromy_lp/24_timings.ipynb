# %%
from time import time

import matplotlib.pyplot as plt
import numpy as np
from hetero_isas.monodromy_lp import (
    MonodromyLPDecomposer,
)
from hetero_isas.monodromy_lp.decomposer import MonodromyLPDecomposerResult
from hetero_isas.monodromy_lp.invariants import recover_local_equivalence
from hetero_isas.monodromy_lp.isa import ISAHandler
from hetero_isas.monodromy_lp.mono_lp_result import plot_histograms
from hetero_isas.zz_parallel_drive.ansatz import BasicCircuitAnsatz
from numpy.random import Philox
from qiskit import QuantumCircuit
from qiskit.circuit import Gate, Parameter
from qiskit.circuit.library import CXGate, CZGate, SwapGate, UnitaryGate, iSwapGate
from qiskit.quantum_info import Operator, average_gate_fidelity, random_unitary
from qiskit.synthesis.two_qubit.local_invariance import two_qubit_local_invariants
from qutip import Qobj
from tqdm.notebook import tqdm
from weylchamber import c1c2c3

generator = Philox(0)

# %matplotlib inline
# Out:
# WARNING:2025-04-14 09:14:04,821:jax._src.xla_bridge:966: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
isa_handler = ISAHandler(
    [
        CXGate(),
        CXGate().power(1 / 2),
        CXGate().power(1 / 3),
        # CXGate().power(1 / 4),
        # CXGate().power(1 / 5),
    ],
    [1.0, 1 / 2, 1 / 3, 1 / 4, 1 / 5],
    ["cx,", "sq[2]cx", "sq[3]cx", "sq[4]cx", "sq[5]cx"],
)

# isa_handler = ISAHandler(
#     [
#         iSwapGate(),
#         iSwapGate().power(1 / 2),
#         iSwapGate().power(1 / 3),
#     ][1:2],
#     [1.0, 1 / 2, 1 / 3][1:2],
#     ["is,", "sq[2]is", "sq[3]is"][1:2],
# )

scipy_decomposer = MonodromyLPDecomposer(isa_handler, use_ordered_sequences=True)
scipy_decomposer.numeric_decomposer.allow_fail = True
cplex_decomposer = MonodromyLPDecomposer(isa_handler, use_ordered_sequences=False)

# %%
# target = SwapGate().to_matrix()
# result_list = []
lp_timings1 = []
numeric_timings1 = []
for _ in tqdm(range(N := 5_000)):
    target = random_unitary(4).to_matrix()
    time_start = time()
    mono_lp_result = scipy_decomposer._best_decomposition(target)
    lp_timings1.append(time() - time_start)
    time_start = time()
    output_qc, lp_result = scipy_decomposer.numeric_decomposer.run(
        target, mono_lp_result, debugging=True
    )
    numeric_timings1.append(time() - time_start)
    # result_list.append(lp_result)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# /home/evm9/hetero_isas/src/hetero_isas/monodromy_lp/invariants.py:94: UserWarning: Tried to recover local equivalence, but the c parameter had a sign difference.
#   warnings.warn(
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [3.12781535e-04 1.26809956e-06 1.74963735e-05]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00082099 0.00243888 0.00325792]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [4.00377593e-05 1.44121718e-02 1.43721331e-02]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [5.56031554e-05 4.04347652e-04 4.59431962e-04]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [1.22217840e-02 8.66513285e-06 2.22673717e-01]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [7.38677892e-05 8.04712539e-03 8.12091408e-03]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00109511 0.00126024 0.00016482]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [3.40183598e-07 1.01534181e-01 6.43738531e-01]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [1.81852585e-05 8.97628162e-04 8.77135053e-04]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00021913 0.00732523 0.00754382]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.04121287 0.0194647  0.35382709]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00075976 0.00014231 0.00027981]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [1.04894605e-04 1.04877715e-04 2.32642834e-07]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [3.93097996e-04 3.84370814e-05 1.10713120e-04]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00176472 0.00914157 0.0109038 ]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00230857 0.00208499 0.00310261]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [5.57478655e-04 6.08900863e-04 5.14140389e-05]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [1.14475253e-04 1.14456212e-04 5.42556862e-08]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00016052 0.00010402 0.00017716]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [1.38128544e-05 2.98329177e-04 3.11475067e-04]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00031957 0.00019074 0.00010864]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [2.96285446e-05 1.14951007e-03 1.11668974e-03]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00224538 0.01106465 0.01329058]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [1.09891191e-04 1.09913509e-04 1.54413080e-08]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [0.00099433 0.00295668 0.00395098]. If this is close to 0, then adjust tolerances.
# Tried to recover local equivalence on gates that were not locally equivalent.                 Often this is a matter of precision. The difference between expected and given                 weyl coords was [7.50297613e-05 1.11792486e-04 8.60478712e-05]. If this is close to 0, then adjust tolerances.

# %%
# target = SwapGate().to_matrix()
# result_list = []
lp_timings2 = []
numeric_timings2 = []
for _ in tqdm(range(N := 1_000)):
    target = random_unitary(4).to_matrix()
    time_start = time()
    mono_lp_result = cplex_decomposer._best_decomposition(target)
    lp_timings2.append(time() - time_start)
    # time_start = time()
    # output_qc, lp_result = cplex_decomposer.numeric_decomposer.run(
    #     target, mono_lp_result, debugging=True
    # )
    # numeric_timings2.append(time() - time_start)
    # result_list.append(lp_result)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# duration historams
fig, ax = plt.subplots(1, 1, figsize=(4, 3))
bins = 64
amax = 0.04  # 0.05  # 0.08

cmap = plt.colormaps.get_cmap("tab10")

# histogram data and colors
# data = [
#     # (numeric_timings1[1:], "1Q numerics (9 RV)"),
#     (lp_timings1[1:], "highs(ILP)"),
#     (lp_timings2[1:], "cplex(MILP)"),
# ]

data = [
    # (numeric_timings1[1:], "1Q numerics (9 RV)"),
    (lp_timings1[1:], "ILP - 2Q sequence"),
    (numeric_timings1[1:], "LM - 1Q numerics"),
]

for (durations, label), color in zip(data, cmap.colors[2:]):
    clipped_data = np.clip(durations, a_min=0, a_max=amax)
    ax.hist(clipped_data, bins, label=label, alpha=0.8, color=color)
    mean = np.mean(durations)
    std = np.std(durations)

    ax.axvline(mean, color=color, linestyle="-", linewidth=1, alpha=0.7)
    ax.axvline(mean + std / 2.0, color=color, linestyle="--", linewidth=1, alpha=0.1)
    ax.axvline(mean - std / 2.0, color=color, linestyle="--", linewidth=1, alpha=0.1)

ax.set_ylabel("Frequency")
ax.set_xlabel("Duration (s)")
ax.legend()

# %%
fig.savefig("lpvsnumerics.svg", bbox_inches="tight")
