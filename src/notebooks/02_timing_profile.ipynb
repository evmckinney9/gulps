# %%
import lovelyplots
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import scienceplots
from qiskit.quantum_info import Operator, average_gate_fidelity
from qiskit.quantum_info.random import random_unitary
from tqdm import tqdm, trange

from gulps.gulps_decomposer import GulpsDecomposer
from gulps.logging_config import logger

logger.setLevel("INFO")
# logger.setLevel("DEBUG")
# Out:
# WARNING:2025-08-04 14:56:49,890:jax._src.xla_bridge:794: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# NOTE, this is expensive but typically you wouldn't need to built all these at once
# either turn precompute_polytope off or
# just save the circuitpolytope data and not go through the expensive build repeatedly
from gulps.isa_library.defined_isas import ISA_LIBRARY
# Out:
# [gulps.isa_library.defined_isas] INFO: Building ISA: iswap_4
# [gulps.isa_library.defined_isas] INFO:   → Coverage set built in 2.52 seconds
# [gulps.isa_library.defined_isas] INFO:   → Expected (Cost: 0.96, Depth: 3.84, Polytope Index: 3.8395746639269444)
# [gulps.isa_library.defined_isas] INFO: Building ISA: cx_3
# [gulps.isa_library.defined_isas] INFO:   → Coverage set built in 1.70 seconds
# [gulps.isa_library.defined_isas] INFO:   → Expected (Cost: 1.67, Depth: 5.00, Polytope Index: 5.001588958196005)
# [gulps.isa_library.defined_isas] INFO: Building ISA: cx_iswap_2_3
# [gulps.isa_library.defined_isas] INFO:   → Coverage set built in 8.57 seconds
# [gulps.isa_library.defined_isas] INFO:   → Expected (Cost: 0.95, Depth: 2.20, Polytope Index: 7.526664966436027)
# [gulps.isa_library.defined_isas] INFO: Building ISA: cx_iswap_swap
# [gulps.isa_library.defined_isas] INFO:   → Coverage set built in 15.40 seconds
# [gulps.isa_library.defined_isas] INFO:   → Expected (Cost: 0.89, Depth: 2.34, Polytope Index: 14.085863787175787)

# %%
# === Extract ISA Benchmark Metadata ===
names = [cfg["name"] for cfg in ISA_LIBRARY]
haar = np.array([cfg["expected_cost"] for cfg in ISA_LIBRARY])
depth = np.array([cfg["expected_sentence_len"] for cfg in ISA_LIBRARY])
poly = np.array([cfg["expected_polytope_index"] for cfg in ISA_LIBRARY])

N = len(names)
colors = cm.tab20(np.linspace(0, 1, N))
markers = ["o", "s", "^", "D", "v", ">", "<", "p", "h", "*"] * ((N // 10) + 1)

sorted_depth = np.argsort(depth)
sorted_poly = np.argsort(poly)
sorted_haar = np.argsort(haar)

# === Plot Summary Metrics ===
with plt.style.context(["ieee", "science", "use_mathtext"]):
    fig, axes = plt.subplots(1, 2, figsize=(7, 2.8))

    axs = axes[0]
    for i, j in enumerate(sorted_depth):
        axs.scatter(i, depth[j], c=[colors[j]], marker=markers[j], s=40, label=names[j])
        axs.set_ylabel("Expected Sentence Length")
        axs.set_xticks([])
        axs.grid(True, axis="y", linestyle="--", alpha=0.4)

    axs = axes[1]
    for i, j in enumerate(sorted_poly):
        axs.scatter(i, poly[j], c=[colors[j]], marker=markers[j], s=40, label=names[j])
        axs.set_ylabel("Expected Polytope Index")
        axs.set_xticks([])
        axs.grid(True, axis="y", linestyle="--", alpha=0.4)

    # axs = axes[2]
    # for i,j in enumerate(sorted_haar):
    #     axs.scatter(
    #         i, haar[j], c=[colors[j]], marker=markers[j], s=40, label=names[j]
    #     )
    #     axs.set_ylabel("Expected Gate Cost")
    #     axs.set_xticks([])
    #     axs.grid(True, axis="y", linestyle="--", alpha=0.4)

    # Show global legend
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(
        handles,
        labels,
        loc="lower center",
        ncol=len(names) // 3,
        bbox_to_anchor=(0.5, -0.2),
    )
    fig.tight_layout()
    plt.show()

# %%
# === Run Fidelity and Timing Benchmarks ===
N = 1000  # Set to 100 for quick test or 1000 for full run
results = []

for config in ISA_LIBRARY:
    name = config["name"]
    decomposer = GulpsDecomposer(gate_set=None, costs=None, isa=config["isa"])
    fidelities, timings = [], []

    # Warm-up (trigger any internal caching paths)
    _ = decomposer._run(random_unitary(4, seed=0))

    for idx in trange(N, desc=f"Running {name}"):
        u = random_unitary(4, seed=idx)
        try:
            v = Operator(decomposer(u))
            fidelities.append(average_gate_fidelity(u, v))
            timings.append(decomposer.last_timing)
        except Exception as e:
            logger.error(f"Error processing unitary {idx}: {e}")
            fidelities.append(-1)  # Use -1 to indicate failure
            timings.append(-1)  # Use -1 to indicate failure

    results.append(
        {
            "name": name,
            "sentence_len": config["expected_sentence_len"],
            "polytope_index": config["expected_polytope_index"],
            "fidelities": fidelities,
            "timings": timings,
        }
    )
# Out:
# Running iswap_4:   1%|          | 9/1000 [00:02<04:23,  3.76it/s][gulps] ERROR: Error processing unitary 9: Cannot recover local equivalence; Weyl differences [1.53733494e-03 1.53079029e-03 6.58835302e-06]
# Running iswap_4:  22%|██▏       | 216/1000 [00:46<01:53,  6.90it/s][gulps] ERROR: Error processing unitary 217: Cannot recover local equivalence; Weyl differences [5.34045004e-04 5.29610605e-04 4.47281235e-06]
# Running iswap_4:  26%|██▋       | 264/1000 [00:57<03:15,  3.76it/s][gulps] ERROR: Error processing unitary 265: Cannot recover local equivalence; Weyl differences [1.49020842e-03 1.48402222e-03 6.22283780e-06]
# Running iswap_4:  39%|███▊      | 386/1000 [01:21<02:19,  4.39it/s][gulps] ERROR: Error processing unitary 386: Cannot recover local equivalence; Weyl differences [1.04207200e-03 1.03781615e-03 4.27233386e-06]
# Running iswap_4:  41%|████      | 410/1000 [01:25<01:04,  9.20it/s][gulps] ERROR: Error processing unitary 410: Cannot recover local equivalence; Weyl differences [7.81785022e-04 7.79400790e-04 2.39305281e-06]
# Running iswap_4:  58%|█████▊    | 583/1000 [02:04<01:25,  4.88it/s][gulps] ERROR: Error processing unitary 584: Cannot recover local equivalence; Weyl differences [1.16071018e-03 1.15755966e-03 3.15260185e-06]
# Running iswap_4:  63%|██████▎   | 629/1000 [02:13<01:14,  4.99it/s][gulps] ERROR: Error processing unitary 629: Cannot recover local equivalence; Weyl differences [1.69383764e-03 1.68876888e-03 5.46067453e-06]
# Running iswap_4:  67%|██████▋   | 674/1000 [02:21<00:45,  7.23it/s][gulps] ERROR: Error processing unitary 674: Cannot recover local equivalence; Weyl differences [5.06647508e-04 5.05999945e-04 6.58146116e-07]
# Running iswap_4:  72%|███████▏  | 718/1000 [02:30<01:11,  3.92it/s][gulps] ERROR: Error processing unitary 718: Cannot recover local equivalence; Weyl differences [1.54753378e-03 1.54332798e-03 4.56266646e-06]
# Running iswap_4:  80%|████████  | 802/1000 [02:46<00:38,  5.12it/s][gulps] ERROR: Error processing unitary 802: Cannot recover local equivalence; Weyl differences [5.15368970e-04 5.15012538e-04 3.66874571e-07]
# Running iswap_4:  86%|████████▌ | 860/1000 [02:57<00:22,  6.35it/s][gulps] ERROR: Error processing unitary 860: Cannot recover local equivalence; Weyl differences [1.16291996e-03 1.15889080e-03 4.03140322e-06]
# Running iswap_4:  98%|█████████▊| 984/1000 [03:20<00:03,  5.06it/s][gulps] ERROR: Error processing unitary 984: Cannot recover local equivalence; Weyl differences [7.76725637e-04 7.76593550e-04 2.83900579e-07]
# Running iswap_4: 100%|██████████| 1000/1000 [03:24<00:00,  4.89it/s]
# Running cx_3: 100%|██████████| 1000/1000 [03:48<00:00,  4.37it/s]
# Running cx_iswap_2_3: 100%|██████████| 1000/1000 [00:40<00:00, 24.42it/s]
# Running cx_iswap_swap: 100%|██████████| 1000/1000 [00:25<00:00, 39.64it/s]

# %%
# === Process Timing Results (std, clipped at 0) ===
numeric_means = []
numeric_err_low = []
numeric_err_high = []

for r in results:
    valid_timings = [
        t["numeric"] for t in r["timings"] if isinstance(t, dict) and t["numeric"] != -1
    ]

    if len(valid_timings) == 0:
        numeric_means.append(np.nan)
        numeric_err_low.append(np.nan)
        numeric_err_high.append(np.nan)
        continue

    median = np.median(valid_timings)
    std = np.std(valid_timings)
    lower = max(median - std, 0)
    upper = median + std

    numeric_means.append(median)
    numeric_err_low.append(median - lower)
    numeric_err_high.append(upper - median)

# === Plot with Consistent ISA Markers and Colors ===
with plt.style.context(["ieee", "science", "use_mathtext"]):
    fig, ax = plt.subplots(figsize=(3.5, 3.5))

    for i, name in enumerate(names):
        if np.isnan(numeric_means[i]):
            continue

        ax.scatter(
            depth[i],
            numeric_means[i],
            # yerr=[[numeric_err_low[i]], [numeric_err_high[i]]],
            # fmt=markers[i],
            color=colors[i],
            marker=markers[i],
            # markersize=6,
            # capsize=3,
            # ecolor="gray",
            # elinewidth=1,
            label=name,
        )
        # ax.annotate(name, (depth[i], numeric_means[i]), fontsize=7)

    ax.set_xlabel("Expected Sentence Length")
    ax.set_ylabel("Median Numeric Time (s)")

    # O(n) fit over valid entries
    valid_idx = [i for i, v in enumerate(numeric_means) if not np.isnan(v)]
    fit = np.poly1d(
        np.polyfit(np.array(depth)[valid_idx], np.array(numeric_means)[valid_idx], 1)
    )
    ax.plot(
        depth,
        fit(depth),
        linestyle="--",
        color="gray",
        label="O(n) fit",
        alpha=0.5,
    )
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(
        handles,
        labels,
        loc="upper right",
        ncol=1,  # len(names),
        bbox_to_anchor=(1.3, 1.0),
    )

    fig.tight_layout()
plt.show()
